# %% [markdown]
# <a href="https://colab.research.google.com/github/darealDanh/practice-1/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('/content/ds_salaries.csv')

# %%
df
# Out:
#         No  Work_yr Exp_level Emp_type                 job_title  Salary  \
# 0        1     2023        SE       FT  Principal Data Scientist   85847
# 1        2     2022        SE       FT              AI Developer  275000
# 2        3     2022        EX       FT        Lead Data Engineer  115222
# 3        4     2023        SE       FT            Data Scientist  175000
# 4        5     2023        SE       FT            Data Scientist  120000
# ...    ...      ...       ...      ...                       ...     ...
# 3750  3751     2020        SE       FT            Data Scientist  412000
# 3751  3752     2021        MI       FT  Principal Data Scientist  151000
# 3752  3753     2020        EN       FT            Data Scientist  105000
# 3753  3754     2020        EN       CT     Business Data Analyst  100000
# 3754  3755     2021        SE       FT      Data Science Manager   94665
#
#      Emp_res Comp_location Comp_size
# 0         ES            ES         L
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   No             3755 non-null   int64
#  1   Work_yr        3755 non-null   int64
#  2   Exp_level      3755 non-null   object
#  3   Emp_type       3755 non-null   object
#  4   job_title      3755 non-null   object
#  5   Salary         3755 non-null   int64
#  6   Emp_res        3755 non-null   object
#  7   Comp_location  3755 non-null   object
#  8   Comp_size      3755 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 264.1+ KB

# %%
df['Salary'].describe()
# Out:
# count      3755.000000
# mean     137570.389880
# std       63055.625278
# min        5132.000000
# 25%       95000.000000
# 50%      135000.000000
# 75%      175000.000000
# max      450000.000000
# Name: Salary, dtype: float64

# %%
Company_size_counts = df['Comp_size'].value_counts()
print(Company_size_counts)
# Out:
# Comp_size
# M    3153
# L     454
# S     148
# Name: count, dtype: int64

# %%
df.groupby('Comp_size')['Salary'].describe()
# Out:
#             count           mean           std     min        25%       50%  \
# Comp_size
# L           454.0  118300.982379  75832.391505  5409.0   60830.75  108500.0
# M          3153.0  143130.548367  58992.813382  5132.0  102100.00  140000.0
# S           148.0   78226.682432  61955.141792  5679.0   35668.00   62146.0
#
#                  75%       max
# Comp_size
# L          159175.00  423834.0
# M          180000.00  450000.0
# S          107481.75  416000.0

# %%
df.groupby('Exp_level')['Salary'].describe()
# Out:
#             count           mean           std      min       25%       50%  \
# Exp_level
# EN          320.0   78546.284375  52225.424309   5409.0   40000.0   70000.0
# EX          114.0  194930.929825  70661.929661  15000.0  145000.0  196000.0
# MI          805.0  104525.939130  54387.685128   5132.0   66837.0  100000.0
# SE         2516.0  153051.071542  56896.263954   8000.0  115000.0  146000.0
#
#                  75%       max
# Exp_level
# EN         110009.25  300000.0
# EX         239000.00  416000.0
# MI         135000.00  450000.0
# SE         185900.00  423834.0

# %%
import matplotlib.pyplot as plt

# %%
df['Salary'].hist(bins=20)
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Histogram of Salary')
plt.show()
